# %% [markdown]
# # Using APIs/Data Structures
# Using the Dark Sky Forecast API at https://developer.forecast.io (Links to an external site.)Links to an external site./, generate a sentence that describes the weather that day.
#
# Right now it is TEMPERATURE degrees out and SUMMARY. Today will be TEMP_FEELING with a high of HIGH_TEMP and a low of LOW_TEMP. RAIN_WARNING.
#
# TEMPERATURE is the current temperature
# SUMMARY is what it currently looks like (partly cloudy, etc - it's "summary" in the dictionary). Lowercase, please.
# TEMP_FEELING is whether it will be hot, warm, cold, or moderate. You will probably use HIGH_TEMP and your own thoughts and feelings to determine this.
# HIGH_TEMP is the high temperature for the day.
# LOW_TEMP is the low temperature for the day.
# RAIN_WARNING is something like "bring your umbrella!" if it is going to rain at some point during the day.
# You can take a look at the documentation, but "current" contains the current conditions and the first element of "daily" is for the current day. But you knew that, right?!
#
# Feel free to steal your old code! I bet that trying to read it will make you depressed and teaches you the value of naming variables.
#
# Once you've accomplished that part, use Mailgun to send yourself an email every morning at 8AM telling you the sentence. The subject line of the email should be something like "8AM Weather forecast: January 1, 1970."
#
# Dates are obtained by doing something like this, using http://strftime.org/ as a reference:
#
# import datetime
# right_now = datetime.datetime.now()
# date_string = right_now.strftime("%Y-%M")
# BONUS: List the forecasted temperatures as the day goes on.

# %%
import requests

# %% [markdown]
# # Send Via API

# %%
### Will use these code later!


# response = requests.post(
#         "https://api.mailgun.net/v3/MY_DOMAIN/messages",
#         auth=("api", "MYAPIKEY"),
#         data={"from": "DIAN ZHANG <dz2383@columbia.edu>",
#               "to": ["dz2383@columbia.edu"],
#               "subject": "Hello",
#               "text": "Testing some Mailgun awesomness!"}) 
# response.text
# Out:
# '{\n  "id": "<20180619193605.1.B7F34C9EA0F52D95@sandbox640aad25f01942ddad29a078ff170d9b.mailgun.org>",\n  "message": "Queued. Thank you."\n}'

# %% [markdown]
# # Dark Sky API

# %%
url ='https://api.darksky.net/forecast/MY_API_KEY/40.785091,-73.968285'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# make it look like a dictionary
data = response.json()
data
# Out:
# {'latitude': 40.785091,
#  'longitude': -73.968285,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1529436966,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'nearestStormDistance': 0,
#   'precipIntensity': 0.002,
#   'precipIntensityError': 0,
#   'precipProbability': 0.28,
#   'precipType': 'rain',
#   'temperature': 87.84,
#   'apparentTemperature': 87.84,
#   'dewPoint': 54.32,
#   'humidity': 0.32,
#   'pressure': 1008.75,
#   'windSpeed': 6.77,
#   'windGust': 7.74,
#   'windBearing': 349,
#   'cloudCover': 0.34,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 302.22},
#  'minutely': {'summary': 'Partly cloudy for the hour.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1529436960,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.27,
#     'precipType': 'rain'},
#    {'time': 1529437020,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.39,
#     'precipType': 'rain'},
#    {'time': 1529437080,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.45,
#     'precipType': 'rain'},
#    {'time': 1529437140,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.47,
#     'precipType': 'rain'},
#    {'time': 1529437200,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.46,
#     'precipType': 'rain'},
#    {'time': 1529437260,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.46,
#     'precipType': 'rain'},
#    {'time': 1529437320,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.42,
#     'precipType': 'rain'},
#    {'time': 1529437380,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.39,
#     'precipType': 'rain'},
#    {'time': 1529437440,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.33,
#     'precipType': 'rain'},
#    {'time': 1529437500,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.3,
#     'precipType': 'rain'},
#    {'time': 1529437560,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.26,
#     'precipType': 'rain'},
#    {'time': 1529437620,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.22,
#     'precipType': 'rain'},
#    {'time': 1529437680,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1529437740,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1529437800,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.13,
#     'precipType': 'rain'},
#    {'time': 1529437860,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.12,
#     'precipType': 'rain'},
#    {'time': 1529437920,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1529437980,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1529438040,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1529438100,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1529438160,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1529438220,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1529438280,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1529438340, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529438400,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1529438460,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1529438520,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1529438580,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1529438640,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1529438700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529438760,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1529438820,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529438880,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529438940,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529439060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529439120,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439180,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439240,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529439360,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439420,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529439540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529439600,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439660,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439720,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439780,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439840,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439900,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529439960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529440020,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529440080,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529440140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529440200,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529440260,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529440320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529440380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1529440440,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529440500,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1529440560, 'precipIntensity': 0, 'precipProbability': 0}]},
#  'hourly': {'summary': 'Partly cloudy starting tomorrow morning.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1529434800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 87.31,
#     'apparentTemperature': 87.31,
#     'dewPoint': 55.43,
#     'humidity': 0.34,
#     'pressure': 1008.83,
#     'windSpeed': 6.48,
#     'windGust': 7.76,
#     'windBearing': 347,
#     'cloudCover': 0.37,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 301.07},
#    {'time': 1529438400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 88.19,
#     'apparentTemperature': 88.19,
#     'dewPoint': 53.54,
#     'humidity': 0.31,
#     'pressure': 1008.7,
#     'windSpeed': 6.96,
#     'windGust': 7.73,
#     'windBearing': 350,
#     'cloudCover': 0.32,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 302.99},
#    {'time': 1529442000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 87.97,
#     'apparentTemperature': 87.97,
#     'dewPoint': 52.94,
#     'humidity': 0.3,
#     'pressure': 1008.92,
#     'windSpeed': 7.08,
#     'windGust': 9.16,
#     'windBearing': 357,
#     'cloudCover': 0.13,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 304.6},
#    {'time': 1529445600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 86.98,
#     'apparentTemperature': 86.98,
#     'dewPoint': 52.61,
#     'humidity': 0.31,
#     'pressure': 1008.96,
#     'windSpeed': 7.49,
#     'windGust': 10.13,
#     'windBearing': 358,
#     'cloudCover': 0.15,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 306.2},
#    {'time': 1529449200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 85.21,
#     'apparentTemperature': 85.21,
#     'dewPoint': 52.77,
#     'humidity': 0.33,
#     'pressure': 1009.31,
#     'windSpeed': 7.58,
#     'windGust': 9.86,
#     'windBearing': 4,
#     'cloudCover': 0.16,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 307.58},
#    {'time': 1529452800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 82.82,
#     'apparentTemperature': 82.82,
#     'dewPoint': 53.02,
#     'humidity': 0.36,
#     'pressure': 1009.75,
#     'windSpeed': 7.3,
#     'windGust': 10.1,
#     'windBearing': 11,
#     'cloudCover': 0.15,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 308.42},
#    {'time': 1529456400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.72,
#     'apparentTemperature': 79.72,
#     'dewPoint': 53.47,
#     'humidity': 0.4,
#     'pressure': 1010.42,
#     'windSpeed': 7.13,
#     'windGust': 12.16,
#     'windBearing': 15,
#     'cloudCover': 0.1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 308.25},
#    {'time': 1529460000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.2,
#     'apparentTemperature': 77.2,
#     'dewPoint': 54.62,
#     'humidity': 0.46,
#     'pressure': 1011.32,
#     'windSpeed': 6.7,
#     'windGust': 11.2,
#     'windBearing': 14,
#     'cloudCover': 0.04,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 307.53},
#    {'time': 1529463600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 74.91,
#     'apparentTemperature': 74.91,
#     'dewPoint': 55.03,
#     'humidity': 0.5,
#     'pressure': 1011.84,
#     'windSpeed': 6.53,
#     'windGust': 13.45,
#     'windBearing': 21,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 306.58},
#    {'time': 1529467200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.11,
#     'apparentTemperature': 73.11,
#     'dewPoint': 55.19,
#     'humidity': 0.53,
#     'pressure': 1012.17,
#     'windSpeed': 6.17,
#     'windGust': 13.82,
#     'windBearing': 22,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 305.35},
#    {'time': 1529470800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 71.82,
#     'apparentTemperature': 71.82,
#     'dewPoint': 54.86,
#     'humidity': 0.55,
#     'pressure': 1012.12,
#     'windSpeed': 5.82,
#     'windGust': 13.85,
#     'windBearing': 29,
#     'cloudCover': 0.04,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.86},
#    {'time': 1529474400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 70.62,
#     'apparentTemperature': 70.62,
#     'dewPoint': 54.59,
#     'humidity': 0.57,
#     'pressure': 1012.18,
#     'windSpeed': 5.51,
#     'windGust': 13.4,
#     'windBearing': 31,
#     'cloudCover': 0.12,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.93},
#    {'time': 1529478000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 69.53,
#     'apparentTemperature': 69.53,
#     'dewPoint': 54,
#     'humidity': 0.58,
#     'pressure': 1012.26,
#     'windSpeed': 5.41,
#     'windGust': 13.23,
#     'windBearing': 28,
#     'cloudCover': 0.24,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.89},
#    {'time': 1529481600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.49,
#     'apparentTemperature': 68.49,
#     'dewPoint': 53.35,
#     'humidity': 0.58,
#     'pressure': 1012.32,
#     'windSpeed': 5.32,
#     'windGust': 13.33,
#     'windBearing': 27,
#     'cloudCover': 0.36,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.23},
#    {'time': 1529485200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.6,
#     'apparentTemperature': 67.6,
#     'dewPoint': 52.81,
#     'humidity': 0.59,
#     'pressure': 1012.35,
#     'windSpeed': 5.4,
#     'windGust': 13.31,
#     'windBearing': 32,
#     'cloudCover': 0.38,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 303.73},
#    {'time': 1529488800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.26,
#     'apparentTemperature': 67.26,
#     'dewPoint': 51.7,
#     'humidity': 0.57,
#     'pressure': 1012.69,
#     'windSpeed': 5.84,
#     'windGust': 13.41,
#     'windBearing': 41,
#     'cloudCover': 0.33,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 304.09},
#    {'time': 1529492400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.37,
#     'apparentTemperature': 68.37,
#     'dewPoint': 52.04,
#     'humidity': 0.56,
#     'pressure': 1012.78,
#     'windSpeed': 5.72,
#     'windGust': 12.23,
#     'windBearing': 47,
#     'cloudCover': 0.46,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 304.29},
#    {'time': 1529496000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.9,
#     'apparentTemperature': 69.9,
#     'dewPoint': 52.86,
#     'humidity': 0.55,
#     'pressure': 1012.8,
#     'windSpeed': 5.68,
#     'windGust': 11.1,
#     'windBearing': 60,
#     'cloudCover': 0.51,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 304.62},
#    {'time': 1529499600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 71.74,
#     'apparentTemperature': 71.74,
#     'dewPoint': 54.6,
#     'humidity': 0.55,
#     'pressure': 1012.72,
#     'windSpeed': 5.41,
#     'windGust': 9.88,
#     'windBearing': 79,
#     'cloudCover': 0.57,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 304.88},
#    {'time': 1529503200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.86,
#     'apparentTemperature': 73.86,
#     'dewPoint': 56.82,
#     'humidity': 0.55,
#     'pressure': 1012.41,
#     'windSpeed': 4.99,
#     'windGust': 8.68,
#     'windBearing': 100,
#     'cloudCover': 0.58,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 305.17},
#    {'time': 1529506800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.22,
#     'apparentTemperature': 76.22,
#     'dewPoint': 58.49,
#     'humidity': 0.54,
#     'pressure': 1012.06,
#     'windSpeed': 4.74,
#     'windGust': 8.24,
#     'windBearing': 119,
#     'cloudCover': 0.56,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 305.2},
#    {'time': 1529510400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.52,
#     'apparentTemperature': 78.52,
#     'dewPoint': 59.11,
#     'humidity': 0.51,
#     'pressure': 1011.58,
#     'windSpeed': 5.27,
#     'windGust': 9.22,
#     'windBearing': 142,
#     'cloudCover': 0.44,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 304.79},
#    {'time': 1529514000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 80.39,
#     'apparentTemperature': 81.02,
#     'dewPoint': 59.25,
#     'humidity': 0.49,
#     'pressure': 1010.98,
#     'windSpeed': 6.22,
#     'windGust': 10.98,
#     'windBearing': 160,
#     'cloudCover': 0.37,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 304.2},
#    {'time': 1529517600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.3,
#     'apparentTemperature': 81.7,
#     'dewPoint': 59.31,
#     'humidity': 0.47,
#     'pressure': 1010.4,
#     'windSpeed': 7.31,
#     'windGust': 12.36,
#     'windBearing': 169,
#     'cloudCover': 0.45,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 304.04},
#    {'time': 1529521200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0006,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 80.91,
#     'apparentTemperature': 81.42,
#     'dewPoint': 59.37,
#     'humidity': 0.48,
#     'pressure': 1009.81,
#     'windSpeed': 8.04,
#     'windGust': 12.82,
#     'windBearing': 174,
#     'cloudCover': 0.63,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 304.72},
#    {'time': 1529524800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 79.46,
#     'apparentTemperature': 79.47,
#     'dewPoint': 59.3,
#     'humidity': 0.5,
#     'pressure': 1009.37,
#     'windSpeed': 8.15,
#     'windGust': 12.83,
#     'windBearing': 174,
#     'cloudCover': 0.74,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 305.9},
#    {'time': 1529528400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0055,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 77.53,
#     'apparentTemperature': 77.53,
#     'dewPoint': 59.46,
#     'humidity': 0.54,
#     'pressure': 1008.91,
#     'windSpeed': 8,
#     'windGust': 12.66,
#     'windBearing': 172,
#     'cloudCover': 0.81,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 306.71},
#    {'time': 1529532000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0157,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 76.21,
#     'apparentTemperature': 76.23,
#     'dewPoint': 60.05,
#     'humidity': 0.57,
#     'pressure': 1008.55,
#     'windSpeed': 7.52,
#     'windGust': 12.52,
#     'windBearing': 163,
#     'cloudCover': 0.86,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 306.69},
#    {'time': 1529535600,
#     'summary': 'Possible Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0365,
#     'precipProbability': 0.22,
#     'precipType': 'rain',
#     'temperature': 74.62,
#     'apparentTemperature': 74.72,
#     'dewPoint': 60.92,
#     'humidity': 0.62,
#     'pressure': 1008.4,
#     'windSpeed': 7.04,
#     'windGust': 12.28,
#     'windBearing': 153,
#     'cloudCover': 0.91,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 306.37},
#    {'time': 1529539200,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0536,
#     'precipProbability': 0.29,
#     'precipType': 'rain',
#     'temperature': 72.49,
#     'apparentTemperature': 72.68,
#     'dewPoint': 61.74,
#     'humidity': 0.69,
#     'pressure': 1008.42,
#     'windSpeed': 5.87,
#     'windGust': 11.86,
#     'windBearing': 156,
#     'cloudCover': 0.95,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 305.85},
#    {'time': 1529542800,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0524,
#     'precipProbability': 0.36,
#     'precipType': 'rain',
#     'temperature': 70.95,
#     'apparentTemperature': 71.25,
#     'dewPoint': 62.43,
#     'humidity': 0.75,
#     'pressure': 1008.33,
#     'windSpeed': 5.34,
#     'windGust': 10.69,
#     'windBearing': 131,
#     'cloudCover': 0.96,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 305.47},
#    {'time': 1529546400,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.043,
#     'precipProbability': 0.42,
#     'precipType': 'rain',
#     'temperature': 70.05,
#     'apparentTemperature': 70.44,
#     'dewPoint': 63.04,
#     'humidity': 0.78,
#     'pressure': 1008.3,
#     'windSpeed': 4.49,
#     'windGust': 9.32,
#     'windBearing': 137,
#     'cloudCover': 0.98,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 305.03},
#    {'time': 1529550000,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0549,
#     'precipProbability': 0.51,
#     'precipType': 'rain',
#     'temperature': 69.09,
#     'apparentTemperature': 69.56,
#     'dewPoint': 63.4,
#     'humidity': 0.82,
#     'pressure': 1008.13,
#     'windSpeed': 4.52,
#     'windGust': 9.43,
#     'windBearing': 134,
#     'cloudCover': 0.99,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 304.13},
#    {'time': 1529553600,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0645,
#     'precipProbability': 0.59,
#     'precipType': 'rain',
#     'temperature': 67.88,
#     'apparentTemperature': 68.4,
#     'dewPoint': 63.44,
#     'humidity': 0.86,
#     'pressure': 1007.89,
#     'windSpeed': 5.53,
#     'windGust': 12.5,
#     'windBearing': 107,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 302.23},
#    {'time': 1529557200,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.1163,
#     'precipProbability': 0.69,
#     'precipType': 'rain',
#     'temperature': 66.66,
#     'apparentTemperature': 67.19,
#     'dewPoint': 63.19,
#     'humidity': 0.89,
#     'pressure': 1007.59,
#     'windSpeed': 6.63,
#     'windGust': 17.28,
#     'windBearing': 76,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 9.78,
#     'ozone': 299.9},
#    {'time': 1529560800,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.1584,
#     'precipProbability': 0.77,
#     'precipType': 'rain',
#     'temperature': 65.66,
#     'apparentTemperature': 66.19,
#     'dewPoint': 62.85,
#     'humidity': 0.91,
#     'pressure': 1007.26,
#     'windSpeed': 7.48,
#     'windGust': 21.14,
#     'windBearing': 55,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 7.56,
#     'ozone': 298.73},
#    {'time': 1529564400,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.1147,
#     'precipProbability': 0.8,
#     'precipType': 'rain',
#     'temperature': 64.79,
#     'apparentTemperature': 65.33,
#     'dewPoint': 62.65,
#     'humidity': 0.93,
#     'pressure': 1006.86,
#     'windSpeed': 7.97,
#     'windGust': 22.67,
#     'windBearing': 45,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 6.62,
#     'ozone': 299.74},
#    {'time': 1529568000,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.071,
#     'precipProbability': 0.78,
#     'precipType': 'rain',
#     'temperature': 64.23,
#     'apparentTemperature': 64.77,
#     'dewPoint': 62.44,
#     'humidity': 0.94,
#     'pressure': 1006.58,
#     'windSpeed': 8.25,
#     'windGust': 23.11,
#     'windBearing': 41,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 6.33,
#     'ozone': 301.85},
#    {'time': 1529571600,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0622,
#     'precipProbability': 0.73,
#     'precipType': 'rain',
#     'temperature': 64.01,
#     'apparentTemperature': 64.49,
#     'dewPoint': 61.98,
#     'humidity': 0.93,
#     'pressure': 1006.48,
#     'windSpeed': 8.33,
#     'windGust': 23.57,
#     'windBearing': 43,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 6.32,
#     'ozone': 303.58},
#    {'time': 1529575200,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0517,
#     'precipProbability': 0.62,
#     'precipType': 'rain',
#     'temperature': 63.98,
#     'apparentTemperature': 64.32,
#     'dewPoint': 61.06,
#     'humidity': 0.9,
#     'pressure': 1006.84,
#     'windSpeed': 8.55,
#     'windGust': 24.77,
#     'windBearing': 41,
#     'cloudCover': 0.99,
#     'uvIndex': 0,
#     'visibility': 6.3,
#     'ozone': 304.23},
#    {'time': 1529578800,
#     'summary': 'Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0546,
#     'precipProbability': 0.55,
#     'precipType': 'rain',
#     'temperature': 64.65,
#     'apparentTemperature': 64.82,
#     'dewPoint': 60.06,
#     'humidity': 0.85,
#     'pressure': 1007.26,
#     'windSpeed': 8.26,
#     'windGust': 25.87,
#     'windBearing': 43,
#     'cloudCover': 0.99,
#     'uvIndex': 0,
#     'visibility': 6.54,
#     'ozone': 304.41},
#    {'time': 1529582400,
#     'summary': 'Light Rain',
#     'icon': 'rain',
#     'precipIntensity': 0.0528,
#     'precipProbability': 0.42,
#     'precipType': 'rain',
#     'temperature': 66.03,
#     'apparentTemperature': 66.04,
#     'dewPoint': 59.26,
#     'humidity': 0.79,
#     'pressure': 1007.7,
#     'windSpeed': 8.54,
#     'windGust': 25.59,
#     'windBearing': 37,
#     'cloudCover': 0.97,
#     'uvIndex': 1,
#     'visibility': 7.47,
#     'ozone': 304.87},
#    {'time': 1529586000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.026,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'temperature': 68.34,
#     'apparentTemperature': 68.34,
#     'dewPoint': 58.57,
#     'humidity': 0.71,
#     'pressure': 1008.09,
#     'windSpeed': 8.39,
#     'windGust': 22.98,
#     'windBearing': 35,
#     'cloudCover': 0.83,
#     'uvIndex': 2,
#     'visibility': 9.74,
#     'ozone': 305.74},
#    {'time': 1529589600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0054,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 70.66,
#     'apparentTemperature': 70.66,
#     'dewPoint': 58,
#     'humidity': 0.64,
#     'pressure': 1008.4,
#     'windSpeed': 7.89,
#     'windGust': 19.23,
#     'windBearing': 32,
#     'cloudCover': 0.77,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 306.59},
#    {'time': 1529593200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.35,
#     'apparentTemperature': 73.35,
#     'dewPoint': 57.62,
#     'humidity': 0.58,
#     'pressure': 1008.74,
#     'windSpeed': 7.57,
#     'windGust': 16.22,
#     'windBearing': 31,
#     'cloudCover': 0.73,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 307.9},
#    {'time': 1529596800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.81,
#     'apparentTemperature': 75.81,
#     'dewPoint': 57.53,
#     'humidity': 0.53,
#     'pressure': 1009,
#     'windSpeed': 7.45,
#     'windGust': 14.5,
#     'windBearing': 31,
#     'cloudCover': 0.64,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 309.71},
#    {'time': 1529600400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.66,
#     'apparentTemperature': 77.66,
#     'dewPoint': 57.64,
#     'humidity': 0.5,
#     'pressure': 1009.25,
#     'windSpeed': 7.22,
#     'windGust': 13.31,
#     'windBearing': 31,
#     'cloudCover': 0.54,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 311.77},
#    {'time': 1529604000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.65,
#     'apparentTemperature': 79.65,
#     'dewPoint': 57.47,
#     'humidity': 0.47,
#     'pressure': 1009.41,
#     'windSpeed': 7.13,
#     'windGust': 12.38,
#     'windBearing': 28,
#     'cloudCover': 0.35,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 313.59},
#    {'time': 1529607600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 81.47,
#     'apparentTemperature': 81.47,
#     'dewPoint': 56.8,
#     'humidity': 0.43,
#     'pressure': 1009.46,
#     'windSpeed': 7.38,
#     'windGust': 11.65,
#     'windBearing': 28,
#     'cloudCover': 0.38,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 314.76}]},
#  'daily': {'summary': 'Rain today through Monday, with high temperatures falling to 71°F on Saturday.',
#   'icon': 'rain',
#   'data': [{'time': 1529380800,
#     'summary': 'Humid throughout the day and partly cloudy until afternoon.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1529400337,
#     'sunsetTime': 1529454697,
#     'moonPhase': 0.22,
#     'precipIntensity': 0.0018,
#     'precipIntensityMax': 0.0162,
#     'precipIntensityMaxTime': 1529388000,
#     'precipProbability': 0.31,
#     'precipType': 'rain',
#     'temperatureHigh': 88.19,
#     'temperatureHighTime': 1529438400,
#     'temperatureLow': 67.26,
#     'temperatureLowTime': 1529488800,
#     'apparentTemperatureHigh': 88.19,
#     'apparentTemperatureHighTime': 1529438400,
#     'apparentTemperatureLow': 67.26,
#     'apparentTemperatureLowTime': 1529488800,
#     'dewPoint': 63.34,
#     'humidity': 0.6,
#     'pressure': 1008.59,
#     'windSpeed': 4.7,
#     'windGust': 13.69,
#     'windGustTime': 1529427600,
#     'windBearing': 335,
#     'cloudCover': 0.36,
#     'uvIndex': 9,
#     'uvIndexTime': 1529427600,
#     'visibility': 10,
#     'ozone': 297.91,
#     'temperatureMin': 74.91,
#     'temperatureMinTime': 1529463600,
#     'temperatureMax': 88.19,
#     'temperatureMaxTime': 1529438400,
#     'apparentTemperatureMin': 74.91,
#     'apparentTemperatureMinTime': 1529463600,
#     'apparentTemperatureMax': 88.19,
#     'apparentTemperatureMaxTime': 1529438400},
#    {'time': 1529467200,
#     'summary': 'Rain starting in the evening.',
#     'icon': 'rain',
#     'sunriseTime': 1529486747,
#     'sunsetTime': 1529541111,
#     'moonPhase': 0.26,
#     'precipIntensity': 0.0112,
#     'precipIntensityMax': 0.0549,
#     'precipIntensityMaxTime': 1529550000,
#     'precipProbability': 0.74,
#     'precipType': 'rain',
#     'temperatureHigh': 81.3,
#     'temperatureHighTime': 1529517600,
#     'temperatureLow': 63.98,
#     'temperatureLowTime': 1529575200,
#     'apparentTemperatureHigh': 81.7,
#     'apparentTemperatureHighTime': 1529517600,
#     'apparentTemperatureLow': 64.32,
#     'apparentTemperatureLowTime': 1529575200,
#     'dewPoint': 57.45,
#     'humidity': 0.58,
#     'pressure': 1010.84,
#     'windSpeed': 3.22,
#     'windGust': 13.85,
#     'windGustTime': 1529470800,
#     'windBearing': 114,
#     'cloudCover': 0.55,
#     'uvIndex': 9,
#     'uvIndexTime': 1529514000,
#     'visibility': 10,
#     'ozone': 304.75,
#     'temperatureMin': 67.26,
#     'temperatureMinTime': 1529488800,
#     'temperatureMax': 81.3,
#     'temperatureMaxTime': 1529517600,
#     'apparentTemperatureMin': 67.26,
#     'apparentTemperatureMinTime': 1529488800,
#     'apparentTemperatureMax': 81.7,
#     'apparentTemperatureMaxTime': 1529517600},
#    {'time': 1529553600,
#     'summary': 'Rain in the morning.',
#     'icon': 'rain',
#     'sunriseTime': 1529573159,
#     'sunsetTime': 1529627524,
#     'moonPhase': 0.29,
#     'precipIntensity': 0.0325,
#     'precipIntensityMax': 0.1584,
#     'precipIntensityMaxTime': 1529560800,
#     'precipProbability': 0.91,
#     'precipType': 'rain',
#     'temperatureHigh': 82.37,
#     'temperatureHighTime': 1529611200,
#     'temperatureLow': 62.8,
#     'temperatureLowTime': 1529661600,
#     'apparentTemperatureHigh': 82.37,
#     'apparentTemperatureHighTime': 1529611200,
#     'apparentTemperatureLow': 62.8,
#     'apparentTemperatureLowTime': 1529661600,
#     'dewPoint': 57.58,
#     'humidity': 0.64,
#     'pressure': 1009.13,
#     'windSpeed': 7.04,
#     'windGust': 25.87,
#     'windGustTime': 1529578800,
#     'windBearing': 46,
#     'cloudCover': 0.68,
#     'uvIndex': 8,
#     'uvIndexTime': 1529600400,
#     'visibility': 10,
#     'ozone': 310.07,
#     'temperatureMin': 63.98,
#     'temperatureMinTime': 1529575200,
#     'temperatureMax': 82.37,
#     'temperatureMaxTime': 1529611200,
#     'apparentTemperatureMin': 64.32,
#     'apparentTemperatureMinTime': 1529575200,
#     'apparentTemperatureMax': 82.37,
#     'apparentTemperatureMaxTime': 1529611200},
#    {'time': 1529640000,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1529659573,
#     'sunsetTime': 1529713935,
#     'moonPhase': 0.33,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1529690400,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 77.04,
#     'temperatureHighTime': 1529694000,
#     'temperatureLow': 63.75,
#     'temperatureLowTime': 1529737200,
#     'apparentTemperatureHigh': 77.04,
#     'apparentTemperatureHighTime': 1529694000,
#     'apparentTemperatureLow': 63.75,
#     'apparentTemperatureLowTime': 1529737200,
#     'dewPoint': 50.79,
#     'humidity': 0.52,
#     'pressure': 1018.13,
#     'windSpeed': 5.94,
#     'windGust': 14.83,
#     'windGustTime': 1529712000,
#     'windBearing': 114,
#     'cloudCover': 0.44,
#     'uvIndex': 8,
#     'uvIndexTime': 1529686800,
#     'visibility': 10,
#     'ozone': 319.44,
#     'temperatureMin': 62.8,
#     'temperatureMinTime': 1529661600,
#     'temperatureMax': 77.04,
#     'temperatureMaxTime': 1529694000,
#     'apparentTemperatureMin': 62.8,
#     'apparentTemperatureMinTime': 1529661600,
#     'apparentTemperatureMax': 77.04,
#     'apparentTemperatureMaxTime': 1529694000},
#    {'time': 1529726400,
#     'summary': 'Rain starting in the evening.',
#     'icon': 'rain',
#     'sunriseTime': 1529745988,
#     'sunsetTime': 1529800344,
#     'moonPhase': 0.36,
#     'precipIntensity': 0.0152,
#     'precipIntensityMax': 0.0589,
#     'precipIntensityMaxTime': 1529805600,
#     'precipProbability': 0.87,
#     'precipType': 'rain',
#     'temperatureHigh': 71.48,
#     'temperatureHighTime': 1529787600,
#     'temperatureLow': 65.98,
#     'temperatureLowTime': 1529830800,
#     'apparentTemperatureHigh': 72.07,
#     'apparentTemperatureHighTime': 1529787600,
#     'apparentTemperatureLow': 66.62,
#     'apparentTemperatureLowTime': 1529830800,
#     'dewPoint': 58.84,
#     'humidity': 0.73,
#     'pressure': 1013.21,
#     'windSpeed': 7.75,
#     'windGust': 22.46,
#     'windGustTime': 1529776800,
#     'windBearing': 109,
#     'cloudCover': 0.93,
#     'uvIndex': 6,
#     'uvIndexTime': 1529773200,
#     'visibility': 10,
#     'ozone': 304.97,
#     'temperatureMin': 63.75,
#     'temperatureMinTime': 1529737200,
#     'temperatureMax': 71.48,
#     'temperatureMaxTime': 1529787600,
#     'apparentTemperatureMin': 63.75,
#     'apparentTemperatureMinTime': 1529737200,
#     'apparentTemperatureMax': 72.07,
#     'apparentTemperatureMaxTime': 1529787600},
#    {'time': 1529812800,
#     'summary': 'Partly cloudy until evening.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1529832405,
#     'sunsetTime': 1529886751,
#     'moonPhase': 0.39,
#     'precipIntensity': 0.0028,
#     'precipIntensityMax': 0.0351,
#     'precipIntensityMaxTime': 1529812800,
#     'precipProbability': 0.45,
#     'precipType': 'rain',
#     'temperatureHigh': 82.62,
#     'temperatureHighTime': 1529870400,
#     'temperatureLow': 66.23,
#     'temperatureLowTime': 1529917200,
#     'apparentTemperatureHigh': 83.72,
#     'apparentTemperatureHighTime': 1529870400,
#     'apparentTemperatureLow': 66.23,
#     'apparentTemperatureLowTime': 1529917200,
#     'dewPoint': 63.53,
#     'humidity': 0.72,
#     'pressure': 1008.23,
#     'windSpeed': 5.88,
#     'windGust': 25.47,
#     'windGustTime': 1529881200,
#     'windBearing': 266,
#     'cloudCover': 0.54,
#     'uvIndex': 8,
#     'uvIndexTime': 1529856000,
#     'visibility': 10,
#     'ozone': 313.75,
#     'temperatureMin': 65.98,
#     'temperatureMinTime': 1529830800,
#     'temperatureMax': 82.62,
#     'temperatureMaxTime': 1529870400,
#     'apparentTemperatureMin': 66.62,
#     'apparentTemperatureMinTime': 1529830800,
#     'apparentTemperatureMax': 83.72,
#     'apparentTemperatureMaxTime': 1529870400},
#    {'time': 1529899200,
#     'summary': 'Rain in the afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1529918824,
#     'sunsetTime': 1529973156,
#     'moonPhase': 0.42,
#     'precipIntensity': 0.0092,
#     'precipIntensityMax': 0.0877,
#     'precipIntensityMaxTime': 1529949600,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'temperatureHigh': 75.79,
#     'temperatureHighTime': 1529942400,
#     'temperatureLow': 58.96,
#     'temperatureLowTime': 1530003600,
#     'apparentTemperatureHigh': 75.79,
#     'apparentTemperatureHighTime': 1529942400,
#     'apparentTemperatureLow': 58.96,
#     'apparentTemperatureLowTime': 1530003600,
#     'dewPoint': 55.13,
#     'humidity': 0.57,
#     'pressure': 1012.69,
#     'windSpeed': 6.89,
#     'windGust': 24.87,
#     'windGustTime': 1529960400,
#     'windBearing': 324,
#     'cloudCover': 0.3,
#     'uvIndex': 7,
#     'uvIndexTime': 1529946000,
#     'visibility': 10,
#     'ozone': 334.86,
#     'temperatureMin': 66.23,
#     'temperatureMinTime': 1529917200,
#     'temperatureMax': 75.79,
#     'temperatureMaxTime': 1529942400,
#     'apparentTemperatureMin': 66.23,
#     'apparentTemperatureMinTime': 1529917200,
#     'apparentTemperatureMax': 75.79,
#     'apparentTemperatureMaxTime': 1529942400},
#    {'time': 1529985600,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1530005245,
#     'sunsetTime': 1530059559,
#     'moonPhase': 0.45,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 79.74,
#     'temperatureHighTime': 1530043200,
#     'temperatureLow': 63.48,
#     'temperatureLowTime': 1530090000,
#     'apparentTemperatureHigh': 79.74,
#     'apparentTemperatureHighTime': 1530043200,
#     'apparentTemperatureLow': 63.48,
#     'apparentTemperatureLowTime': 1530090000,
#     'dewPoint': 46.22,
#     'humidity': 0.45,
#     'pressure': 1023.47,
#     'windSpeed': 0.47,
#     'windGust': 16.36,
#     'windGustTime': 1530068400,
#     'windBearing': 311,
#     'cloudCover': 0,
#     'uvIndex': 10,
#     'uvIndexTime': 1530032400,
#     'visibility': 10,
#     'ozone': 345.12,
#     'temperatureMin': 58.96,
#     'temperatureMinTime': 1530003600,
#     'temperatureMax': 79.74,
#     'temperatureMaxTime': 1530043200,
#     'apparentTemperatureMin': 58.96,
#     'apparentTemperatureMinTime': 1530003600,
#     'apparentTemperatureMax': 79.74,
#     'apparentTemperatureMaxTime': 1530043200}]},
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 0.423,
#   'units': 'us'},
#  'offset': -4}

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
data['currently']
# Out:
# {'time': 1529436966,
#  'summary': 'Partly Cloudy',
#  'icon': 'partly-cloudy-day',
#  'nearestStormDistance': 0,
#  'precipIntensity': 0.002,
#  'precipIntensityError': 0,
#  'precipProbability': 0.28,
#  'precipType': 'rain',
#  'temperature': 87.84,
#  'apparentTemperature': 87.84,
#  'dewPoint': 54.32,
#  'humidity': 0.32,
#  'pressure': 1008.75,
#  'windSpeed': 6.77,
#  'windGust': 7.74,
#  'windBearing': 349,
#  'cloudCover': 0.34,
#  'uvIndex': 5,
#  'visibility': 10,
#  'ozone': 302.22}

# %%
data['daily'].keys()
# Out:
# dict_keys(['summary', 'icon', 'data'])

# %%
# Right now it is TEMPERATURE degrees out and SUMMARY. 
# TEMPERATURE:
temperature = (data['currently']['apparentTemperature'])
print(temperature)
# SUMMARY:
summary = data['currently']['summary']
summary
# Out:
# 87.84
# 'Partly Cloudy'

# %%
# I defined: 
# Cold: 55 degrees and below

# Cool: 56 to 65 degrees

# Mild: 66 to  75 degrees

# Warm: 75 to 85 degrees

# Hot: Above 85 degrees

# %%
high_temp = data['daily']['data'][0]['temperatureHigh']
high_temp
# Out:
# 88.19

# %%
low_temp = data['daily']['data'][0]['temperatureLow']
low_temp
# Out:
# 67.26

# %%
if high_temp >= 85:
    temp_feeling = "hot"
elif 75<= high_temp <85:
    temp_feeling ="warm"
elif 66 <= high_temp <75:
    temp_feeling="mild"
elif 56<= high_temp<66:
    temp_feeling="cool"
elif high_temp <56:
    temp_feeling="cold"

temp_feeling
# Out:
# 'hot'

# %%
data['daily']['data'][0]['icon']
# Out:
# 'partly-cloudy-day'

# %%
daily_summary = data['daily']['data'][0]['icon']

if daily_summary =="rain":
    rain_warning = "Bring your umberalla!"
else:
    rain_warning = "It won't rain today!"

# %%
rain_warning
# Out:
# "It won't rain today!"

# %%
# Right now it is TEMPERATURE degrees out and SUMMARY. 
# Today will be TEMP_FEELING with a high of HIGH_TEMP and a low of LOW_TEMP. RAIN_WARNING.

# TEMPERATURE is the current temperature
# SUMMARY is what it currently looks like (partly cloudy, etc - it's "summary" in the dictionary). Lowercase, please.
# TEMP_FEELING is whether it will be hot, warm, cold, or moderate. You will probably use HIGH_TEMP and your own thoughts and feelings to determine this.
# HIGH_TEMP is the high temperature for the day.
# LOW_TEMP is the low temperature for the day.
# RAIN_WARNING is something like "bring your umbrella!" if it is going to rain at some point during the day.

# %% [markdown]
# # This is the final sentences I generated:

# %%
# I want to generate sentences:

weather_text = "Right now it is {} F degrees out and {}. Today will be {} with a high of {} and a low of {} F degree. {}".format(temperature,summary,temp_feeling,high_temp,low_temp,rain_warning)
print(weather_text)
# Out:
# Right now it is 87.84 F degrees out and Partly Cloudy. Today will be hot with a high of 88.19 and a low of 67.26 F degree. It won't rain today!

# %% [markdown]
# # Set time

# %%
# %B month
# %d day
#% Y
### useful website: http://strftime.org/

import datetime
right_now = datetime.datetime.now()
date_string = right_now.strftime("%B-%d-%Y")

# %% [markdown]
# # Send the actual weather email!

# %%
subject_text = "8AM Weather forecast: {}".format(date_string)

# %%
response = requests.post(
        "https://api.mailgun.net/v3/mysandbox.mailgun.org/messages",
        auth=("api", "MY_API"),
        data={"from": "DIAN ZHANG <dz2383@columbia.edu>",
              "to": ["dz2383@columbia.edu"],
              "subject": subject_text,
              "text": weather_text}) 
response.text
# Out:
# '{\n  "id": "<20180619200722.1.3E041B6FC0309250@sandbox640aad25f01942ddad29a078ff170d9b.mailgun.org>",\n  "message": "Queued. Thank you."\n}'

# %%
# Because of submitting it online, I removed the API key and my sandbox domain
